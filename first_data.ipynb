# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
import sys
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import *
from scipy import stats
import statsmodels.api as sm

# %%
data1 = pd.read_csv('data1.txt', sep=" ")

# %%
data1
# Out:
#             y        x1  x2        x3        x4
# 1    0.560787  0.549867   9  0.077448  0.231227
# 2    0.064530  0.604434   7  0.905245  0.804974
# 3   -1.141358  1.129739   8  0.931991  0.982393
# 4   -0.687120  0.311511  10  0.760244  0.625926
# 5   -0.979358  1.045094  13  0.365114  0.564888
# ..        ...       ...  ..       ...       ...
# 246 -0.270232  0.658893  13  0.061115  0.231365
# 247  1.310052  0.327617  11  0.986719  0.791902
# 248  1.693189  0.438592   7  0.033960  0.139212
# 249  0.150314  0.809657   7  0.848628  0.827820
# 250  0.314554  0.536249   9  0.272468  0.372543
#
# [250 rows x 5 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250 entries, 1 to 250
# Data columns (total 5 columns):
# y     250 non-null float64
# x1    250 non-null float64
# x2    250 non-null int64
# x3    250 non-null float64
# x4    250 non-null float64
# dtypes: float64(4), int64(1)
# memory usage: 11.7 KB

# %% [markdown]
# # Normalize the data:

# %%
data1 = (data1 - data1.mean())/data1.std()
data1.head()
# Out:
#           y        x1        x2        x3        x4
# 1  0.562885 -0.214164 -0.436942 -1.220661 -1.120604
# 2  0.056483 -0.090226 -1.019532  1.028541  0.824176
# 3 -1.174057  1.102906 -0.728237  1.101212  1.425557
# 4 -0.710534 -0.755543 -0.145647  0.634560  0.217271
# 5 -1.008746  0.910651  0.728237 -0.439046  0.010376

# %% [markdown]
# # Create matrices and set hyperparameters:

# %%
#setting the matrixes
X = data1[["x1","x2","x3","x4"]]
#ones = np.ones([X.shape[0],1])
#X = np.concatenate((ones,X),axis=1)

# %%
X=sm.add_constant(X)
# Out:
# C:\Users\HRITIK\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
Y = data1[["y"]] #.values converts it from pandas.core.frame.DataFrame to numpy.ndarray

# %%
Y
# Out:
#             y
# 1    0.562885
# 2    0.056483
# 3   -1.174057
# 4   -0.710534
# 5   -1.008746
# ..        ...
# 246 -0.285122
# 247  1.327468
# 248  1.718437
# 249  0.144021
# 250  0.311619
#
# [250 rows x 1 columns]

# %%
#X[["x1^2","x2^2","x3^2","x4^2"]]=[X["x1"]*X["x1"],X["x2"]*X["x2"],X["x3"]*X["x3"],X["x4"]*X["x4"]]
X["x1^2"]=X["x1"]*X["x1"]
X["x2^2"]=X["x2"]*X["x2"]
X["x3^2"]=X["x3"]*X["x3"]
X["x4^2"]=X["x4"]*X["x4"]
X["x1^3"]=X["x1"]*X["x1"]*X["x1"]
X["x2^3"]=X["x2"]*X["x2"]*X["x2"]
X["x3^3"]=X["x3"]*X["x3"]*X["x3"]
X["x4^3"]=X["x4"]*X["x4"]*X["x4"]

# %%
X
# Out:
#      const        x1        x2        x3        x4      x1^2      x2^2  \
# 1      1.0 -0.214164 -0.436942 -1.220661 -1.120604  0.045866  0.190918
# 2      1.0 -0.090226 -1.019532  1.028541  0.824176  0.008141  1.039445
# 3      1.0  1.102906 -0.728237  1.101212  1.425557  1.216401  0.530329
# 4      1.0 -0.755543 -0.145647  0.634560  0.217271  0.570845  0.021213
# 5      1.0  0.910651  0.728237 -0.439046  0.010376  0.829285  0.530329
# ..     ...       ...       ...       ...       ...       ...       ...
# 246    1.0  0.033469  0.728237 -1.265038 -1.120138  0.001120  0.530329
# 247    1.0 -0.718963  0.145647  1.249913  0.779867  0.516908  0.021213
# 248    1.0 -0.466905 -1.019532 -1.338822 -1.432500  0.218000  1.039445
# 249    1.0  0.375899 -1.019532  0.874709  0.901614  0.141300  1.039445
# 250    1.0 -0.245094 -0.436942 -0.690772 -0.641599  0.060071  0.190918
#
#          x3^2      x4^2      x1^3      x2^3      x3^3      x4^3
# ...

# %%
import seaborn as sns
import sys
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import *
from scipy import stats
import statsmodels.api as sm

# %%
model = sm.OLS(Y, X).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.7903
# Date:                Fri, 20 Nov 2020   Prob (F-statistic):              0.660
# Time:                        23:03:25   Log-Likelihood:                -349.33
# No. Observations:                 250   AIC:                             724.7
# Df Residuals:                     237   BIC:                             770.4
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0354      0.148     -0.239      0.812      -0.328       0.257
# ...

# %%
X.corr()
# Out:
#        const        x1        x2        x3        x4      x1^2      x2^2  \
# const    NaN       NaN       NaN       NaN       NaN       NaN       NaN
# x1       NaN  1.000000 -0.047762  0.038554  0.479816  0.647448  0.012539
# x2       NaN -0.047762  1.000000 -0.051312 -0.067004 -0.093826  0.460914
# x3       NaN  0.038554 -0.051312  1.000000  0.894548  0.006748 -0.116746
# x4       NaN  0.479816 -0.067004  0.894548  1.000000  0.295768 -0.095717
# x1^2     NaN  0.647448 -0.093826  0.006748  0.295768  1.000000 -0.022862
# x2^2     NaN  0.012539  0.460914 -0.116746 -0.095717 -0.022862  1.000000
# x3^2     NaN -0.027400  0.058682 -0.121990 -0.120238 -0.108840  0.095677
# x4^2     NaN  0.269285  0.046289 -0.070211  0.058681  0.451078  0.021843
# x1^3     NaN  0.686216 -0.054908  0.033265  0.336447  0.942978 -0.008083
# x2^3     NaN -0.024682  0.535924 -0.091426 -0.090598 -0.035564  0.944998
# x3^3     NaN  0.066390 -0.065826  0.953023  0.865505  0.021819 -0.138309
# ...

# %%
X.drop(["const"],axis=1, inplace= True)

# %%
model2 = sm.OLS(Y, X).fit()

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.038
# Model:                            OLS   Adj. R-squared (uncentered):             -0.010
# Method:                 Least Squares   F-statistic:                             0.7887
# Date:                Fri, 20 Nov 2020   Prob (F-statistic):                       0.662
# Time:                        23:03:26   Log-Likelihood:                         -349.36
# No. Observations:                 250   AIC:                                      722.7
# Df Residuals:                     238   BIC:                                      765.0
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
X.drop(["x2"],axis=1, inplace= True)
model3 = sm.OLS(Y, X).fit()
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.038
# Model:                            OLS   Adj. R-squared (uncentered):             -0.006
# Method:                 Least Squares   F-statistic:                             0.8610
# Date:                Fri, 20 Nov 2020   Prob (F-statistic):                       0.579
# Time:                        23:03:26   Log-Likelihood:                         -349.38
# No. Observations:                 250   AIC:                                      720.8
# Df Residuals:                     239   BIC:                                      759.5
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
X.drop(["x3"],axis=1, inplace= True)
model3 = sm.OLS(Y, X).fit()
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.037
# Model:                            OLS   Adj. R-squared (uncentered):             -0.003
# Method:                 Least Squares   F-statistic:                             0.9201
# Date:                Fri, 20 Nov 2020   Prob (F-statistic):                       0.515
# Time:                        23:03:26   Log-Likelihood:                         -349.53
# No. Observations:                 250   AIC:                                      719.1
# Df Residuals:                     240   BIC:                                      754.3
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
X.drop(["x3^2"],axis=1, inplace= True)
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.037
# Model:                            OLS   Adj. R-squared (uncentered):              0.001
# Method:                 Least Squares   F-statistic:                              1.022
# Date:                Fri, 20 Nov 2020   Prob (F-statistic):                       0.423
# Time:                        23:03:26   Log-Likelihood:                         -349.55
# No. Observations:                 250   AIC:                                      717.1
# Df Residuals:                     241   BIC:                                      748.8
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
X.corr()
# Out:
#             x1        x4      x1^2      x2^2      x4^2      x1^3      x2^3  \
# x1    1.000000  0.479816  0.647448  0.012539  0.269285  0.686216 -0.024682
# x4    0.479816  1.000000  0.295768 -0.095717  0.058681  0.336447 -0.090598
# x1^2  0.647448  0.295768  1.000000 -0.022862  0.451078  0.942978 -0.035564
# x2^2  0.012539 -0.095717 -0.022862  1.000000  0.021843 -0.008083  0.944998
# x4^2  0.269285  0.058681  0.451078  0.021843  1.000000  0.432374  0.062382
# x1^3  0.686216  0.336447  0.942978 -0.008083  0.432374  1.000000 -0.016281
# x2^3 -0.024682 -0.090598 -0.035564  0.944998  0.062382 -0.016281  1.000000
# x3^3  0.066390  0.865505  0.021819 -0.138309 -0.113684  0.041761 -0.122121
# x4^3  0.626195  0.808536  0.550580 -0.063945  0.330763  0.600982 -0.069600
#
#           x3^3      x4^3
# x1    0.066390  0.626195
# x4    0.865505  0.808536
# x1^2  0.021819  0.550580
# x2^2 -0.138309 -0.063945
# x4^2 -0.113684  0.330763
# x1^3  0.041761  0.600982
# x2^3 -0.122121 -0.069600
# ...

# %%
X.drop(["x3^3"],axis=1, inplace= True)
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.036
# Model:                            OLS   Adj. R-squared (uncentered):              0.004
# Method:                 Least Squares   F-statistic:                              1.120
# Date:                Fri, 20 Nov 2020   Prob (F-statistic):                       0.350
# Time:                        23:03:27   Log-Likelihood:                         -349.69
# No. Observations:                 250   AIC:                                      715.4
# Df Residuals:                     242   BIC:                                      743.6
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
X.corr()
# Out:
#             x1        x4      x1^2      x2^2      x4^2      x1^3      x2^3  \
# x1    1.000000  0.479816  0.647448  0.012539  0.269285  0.686216 -0.024682
# x4    0.479816  1.000000  0.295768 -0.095717  0.058681  0.336447 -0.090598
# x1^2  0.647448  0.295768  1.000000 -0.022862  0.451078  0.942978 -0.035564
# x2^2  0.012539 -0.095717 -0.022862  1.000000  0.021843 -0.008083  0.944998
# x4^2  0.269285  0.058681  0.451078  0.021843  1.000000  0.432374  0.062382
# x1^3  0.686216  0.336447  0.942978 -0.008083  0.432374  1.000000 -0.016281
# x2^3 -0.024682 -0.090598 -0.035564  0.944998  0.062382 -0.016281  1.000000
# x4^3  0.626195  0.808536  0.550580 -0.063945  0.330763  0.600982 -0.069600
#
#           x4^3
# x1    0.626195
# x4    0.808536
# x1^2  0.550580
# x2^2 -0.063945
# x4^2  0.330763
# x1^3  0.600982
# x2^3 -0.069600
# x4^3  1.000000

# %%
X.drop(["x4^2"],axis=1, inplace= True)
model = sm.OLS(Y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.035
# Model:                            OLS   Adj. R-squared (uncentered):              0.007
# Method:                 Least Squares   F-statistic:                              1.267
# Date:                Fri, 20 Nov 2020   Prob (F-statistic):                       0.267
# Time:                        23:03:27   Log-Likelihood:                         -349.75
# No. Observations:                 250   AIC:                                      713.5
# Df Residuals:                     243   BIC:                                      738.2
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
X.corr()
# Out:
#             x1        x4      x1^2      x2^2      x1^3      x2^3      x4^3
# x1    1.000000  0.479816  0.647448  0.012539  0.686216 -0.024682  0.626195
# x4    0.479816  1.000000  0.295768 -0.095717  0.336447 -0.090598  0.808536
# x1^2  0.647448  0.295768  1.000000 -0.022862  0.942978 -0.035564  0.550580
# x2^2  0.012539 -0.095717 -0.022862  1.000000 -0.008083  0.944998 -0.063945
# x1^3  0.686216  0.336447  0.942978 -0.008083  1.000000 -0.016281  0.600982
# x2^3 -0.024682 -0.090598 -0.035564  0.944998 -0.016281  1.000000 -0.069600
# x4^3  0.626195  0.808536  0.550580 -0.063945  0.600982 -0.069600  1.000000

# %%
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.022
# Model:                            OLS   Adj. R-squared (uncentered):             -0.002
# Method:                 Least Squares   F-statistic:                             0.9276
# Date:                Fri, 20 Nov 2020   Prob (F-statistic):                       0.476
# Time:                        23:03:57   Log-Likelihood:                         -351.41
# No. Observations:                 250   AIC:                                      714.8
# Df Residuals:                     244   BIC:                                      736.0
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
